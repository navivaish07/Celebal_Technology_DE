# %%
import pandas as pd
import pyarrow as pa

from deltalake import DeltaTable
from deltalake import write_deltalake

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import pandas as pd

df = pd.read_csv(
    r"D:\Celebal\delta-lake-assignment\DATA\Sample - Superstore.csv",
    encoding="latin1"
)

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (9994, 21)

# %%
print(df.columns.tolist())
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.fillna({
    "Postal Code": 0,
    "Customer Name": "Unknown",
    "Product Name": "Unknown"
}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df.drop_duplicates(inplace=True)

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
import pyarrow as pa
from deltalake import write_deltalake

table = pa.Table.from_pandas(df)

write_deltalake(
    "../data/customer_delta",
    table,
    mode="overwrite"
)

print("Delta table created successfully!")
# Out:
# Delta table created successfully!

# %%
from deltalake import DeltaTable

dt = DeltaTable("../data/customer_delta")

delta_df = dt.to_pandas()

delta_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
incremental_df = pd.DataFrame({
    "Row ID": [1, 2, 10000, 10001],
    "Order ID": ["CA-2016-152156", "CA-2016-152156", "CA-2026-999999", "CA-2026-999998"],
    "Order Date": ["08-11-2016", "08-11-2016", "01-08-2026", "01-08-2026"],
    "Ship Date": ["11-11-2016", "11-11-2016", "03-08-2026", "03-08-2026"],
    "Ship Mode": ["Second Class", "Second Class", "Standard Class", "First Class"],
    "Customer ID": ["CG-12520", "CG-12520", "VD-10001", "VD-10002"],
    "Customer Name": ["Claire Gute", "Claire Gute", "Vaishnavi Dhanwate", "Test Customer"],
    "Segment": ["Consumer", "Consumer", "Corporate", "Consumer"],
    "Country": ["United States", "United States", "India", "India"],
    "City": ["Henderson", "Henderson", "Pune", "Mumbai"],
    "State": ["Kentucky", "Kentucky", "Maharashtra", "Maharashtra"],
    "Postal Code": [42420, 42420, 411001, 400001],
    "Region": ["South", "South", "West", "West"],
    "Product ID": ["FUR-BO-10001798", "FUR-CH-10000454", "TEC-NEW-001", "OFF-NEW-002"],
    "Category": ["Furniture", "Furniture", "Technology", "Office Supplies"],
    "Sub-Category": ["Bookcases", "Chairs", "Accessories", "Paper"],
    "Product Name": ["Updated Bookcase", "Updated Chair", "Wireless Mouse", "Notebook"],
    "Sales": [300.00, 500.00, 1200.00, 250.00],
    "Quantity": [2, 3, 5, 10],
    "Discount": [0.10, 0.00, 0.05, 0.00],
    "Profit": [50.00, 80.00, 300.00, 60.00]
})

# %%
incremental_df.to_csv("../data/customer_incremental.csv", index=False)

incremental_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2   10000  CA-2026-999999  01-08-2026  03-08-2026  Standard Class    VD-10001
# 3   10001  CA-2026-999998  01-08-2026  03-08-2026     First Class    VD-10002
#
#         Customer Name    Segment        Country       City  ... Postal Code  \
# 0         Claire Gute   Consumer  United States  Henderson  ...       42420
# 1         Claire Gute   Consumer  United States  Henderson  ...       42420
# 2  Vaishnavi Dhanwate  Corporate          India       Pune  ...      411001
# 3       Test Customer   Consumer          India     Mumbai  ...      400001
#
#    Region       Product ID         Category Sub-Category      Product Name  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases  Updated Bookcase
# ...

# %%
master_df = dt.to_pandas()

master_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
master_df.set_index("Order ID", inplace=True)
incremental_df.set_index("Order ID", inplace=True)

# %%
master_df = dt.to_pandas()

# %%
master_df.set_index("Row ID", inplace=True)
incremental_df.set_index("Row ID", inplace=True)

# %%
master_df.update(incremental_df)

# %%
new_records = incremental_df.loc[
    ~incremental_df.index.isin(master_df.index)
]

master_df = pd.concat([master_df, new_records])

master_df.reset_index(inplace=True)

# %%
master_df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
master_df.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
# 9994   10000             NaN  01-08-2026  03-08-2026  Standard Class
# 9995   10001             NaN  01-08-2026  03-08-2026     First Class
#
#      Customer ID       Customer Name    Segment        Country         City  \
# 9986    ML-17410        Maris LaWare   Consumer  United States  Los Angeles
# ...

# %%
import pyarrow as pa
from deltalake import write_deltalake

table = pa.Table.from_pandas(master_df)

write_deltalake(
    "../data/customer_delta",
    table,
    mode="overwrite"
)

print("Updated Delta Table Saved Successfully!")
# Out:
# Updated Delta Table Saved Successfully!

# %%
print("Total Rows:", len(master_df))
# Out:
# Total Rows: 9996

# %%
print("Duplicate Records:", master_df.duplicated().sum())
# Out:
# Duplicate Records: 0

# %%
print(master_df.isnull().sum())
# Out:
# Row ID           0
# Order ID         2
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
print("Unique Row IDs:", master_df["Row ID"].nunique())
# Out:
# Unique Row IDs: 9996

# %%
master_df[master_df["Row ID"].isin([10000, 10001])]
# Out:
#       Row ID Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 9994   10000      NaN  01-08-2026  03-08-2026  Standard Class    VD-10001
# 9995   10001      NaN  01-08-2026  03-08-2026     First Class    VD-10002
#
#            Customer Name    Segment Country    City  ... Postal Code  Region  \
# 9994  Vaishnavi Dhanwate  Corporate   India    Pune  ...      411001    West
# 9995       Test Customer   Consumer   India  Mumbai  ...      400001    West
#
#        Product ID         Category Sub-Category    Product Name   Sales  \
# 9994  TEC-NEW-001       Technology  Accessories  Wireless Mouse  1200.0
# 9995  OFF-NEW-002  Office Supplies        Paper        Notebook   250.0
#
#       Quantity  Discount  Profit
# 9994         5      0.05   300.0
# 9995        10      0.00    60.0
#
# [2 rows x 21 columns]

# %%
master_df[master_df["Row ID"].isin([1, 2])]
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category      Product Name  Sales  Quantity  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Updated Bookcase  300.0         2
# 1  FUR-CH-10000454  Furniture       Chairs     Updated Chair  500.0         3
#
#    Discount  Profit
# 0       0.1    50.0
# 1       0.0    80.0
#
# [2 rows x 21 columns]
